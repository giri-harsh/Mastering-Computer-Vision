# %% [markdown]
# ### Crop Image

# %%
import os
import cv2

# %%
img_path = cv2.imread(r'C:\Work\Programing Language\Python\Libraries\OpenCV\data\img.png')
img = img_path
# cv2.imshow('image',img)
# cv2.waitKey(0)

# %%
img.shape
# Out:
# (148, 148, 3)

# %%
cropped_img = img[100:100,40:40]
cv2.imshow('imgage',cropped_img)
cv2.waitKey(4000)
# Out:
# 113
