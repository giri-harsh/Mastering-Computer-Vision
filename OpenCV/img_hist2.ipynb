# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img1 = cv2.imread(r"C:\Work\Programing Language\Python\Libraries\OpenCV\data\img_1.png")
plt.imshow(img1)

# %%
img1 = cv2.imread(r"C:\Work\Programing Language\Python\Libraries\OpenCV\data\img_1.png")
img2 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)

# while True:
#     cv2.imshow('img',img2)
#     if cv2.waitKey(1) & 0xff ==ord('x'):
#         break
# cv2.destroyAllWindows()

# %%
plt.imshow(img2)

# %%
plt.imshow(img1)

# %%
hist_val = cv2.calcHist([img1],channels=[0],mask=None,histSize=[256],ranges=[0,256])

# %%
hist_val.shape
# Out:
# (256, 1)

# %%
plt.plot(hist_val)
