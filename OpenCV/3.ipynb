# %%
import os
import cv2

# %%
img_path = cv2.imread(r'C:\Work\Programing Language\Python\Libraries\OpenCV\data\img.png')

# %%
img = img_path
# cv2.imshow('image',img)
# cv2.waitKey(0)

# %%
img.shape
# Out:
# (148, 148, 3)

# %% [markdown]
# ### Resize image

# %%
resize_img = cv2.resize(img , (74,74))

# %%
resize_img.shape
# cv2.imshow('image',img)
# cv2.waitKey(0)
# Out:
# (74, 74, 3)
