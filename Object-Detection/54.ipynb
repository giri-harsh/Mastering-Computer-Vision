# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
nadia = cv2.imread(r"C:\Work\Programing Language\Python\Libraries\OpenCV\data\img_11.png",0)
denis = cv2.imread(r"C:\Work\Programing Language\Python\Libraries\OpenCV\data\img_12.png",0)
solvay = cv2.imread(r"C:\Work\Programing Language\Python\Libraries\OpenCV\data\img_13.png",0)

# %%
plt.imshow(nadia,cmap='gray')

# %%
cv2.CascadeClassifier()
